# %%
get_ipython().system('pip install folium pandas')
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2026.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2026.4.22)

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
spacex_df = pd.read_csv(URL)

# %%
# Select relevant columns for map visualization
launch_sites_df = spacex_df.groupby(['Launch Site', 'Lat', 'Long'], as_index=False).first()

# Get the center coordinates for the map (e.g., first launch site)
# Or calculate the mean of all launch sites for a more central view
center_lat = spacex_df['Lat'].mean()
center_lon = spacex_df['Long'].mean()

# Create a Folium map object
# Set initial zoom level to 5
NASA_coordinates = [center_lat, center_lon]

# create a map at NASA coordinated with a zoom level of 4
site_map = folium.Map(location=NASA_coordinates, zoom_start=4)

# Add markers for each launch site
for index, site in launch_sites_df.iterrows():
    folium.Marker(
        [site['Lat'], site['Long']],
        popup=site['Launch Site'],
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(site_map)

# Display the map
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc6ae45016596fbf1f8ca8f25474c884 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc6ae45016596fbf1f8ca8f25474c884&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc6ae45016596fbf1f8ca8f25474c884 = L.map(
#                 &quot;map_bc6ae45016596fbf1f8ca8f25474c884&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b64a19925e3918e7c5dc5d92da368a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96b64a19925e3918e7c5dc5d92da368a.addTo(map_bc6ae45016596fbf1f8ca8f25474c884);
#
#
#             var marker_b63568f67f9da368ac555a1ea3597d59 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_bc6ae45016596fbf1f8ca8f25474c884);
#
#
#             var icon_49e7210459288208f8e381d46fa480ae = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9ece8314eefcf2d484f8304dab761e9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32f8b2ed14bfa62713bdfbc7ed44fe29 = $(`&lt;div id=&quot;html_32f8b2ed14bfa62713bdfbc7ed44fe29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9ece8314eefcf2d484f8304dab761e9d.setContent(html_32f8b2ed14bfa62713bdfbc7ed44fe29);
#
#
#
#         marker_b63568f67f9da368ac555a1ea3597d59.bindPopup(popup_9ece8314eefcf2d484f8304dab761e9d)
#         ;
#
#
#
#
#                 marker_b63568f67f9da368ac555a1ea3597d59.setIcon(icon_49e7210459288208f8e381d46fa480ae);
#
#
#             var marker_58f4f5e74ee5bc9cb76f518c08041d01 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {
# }
#             ).addTo(map_bc6ae45016596fbf1f8ca8f25474c884);
#
#
#             var icon_86ce972b944282b35847ef2c829122fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_88979cac197c816e351818a3c05d1f9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7cab693061030e9e9b100fac23d8be2 = $(`&lt;div id=&quot;html_d7cab693061030e9e9b100fac23d8be2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_88979cac197c816e351818a3c05d1f9f.setContent(html_d7cab693061030e9e9b100fac23d8be2);
#
#
#
#         marker_58f4f5e74ee5bc9cb76f518c08041d01.bindPopup(popup_88979cac197c816e351818a3c05d1f9f)
#         ;
#
#
#
#
#                 marker_58f4f5e74ee5bc9cb76f518c08041d01.setIcon(icon_86ce972b944282b35847ef2c829122fd);
#
#
#             var marker_03521bbe9ae2039149529c7158d770f8 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {
# }
#             ).addTo(map_bc6ae45016596fbf1f8ca8f25474c884);
#
#
#             var icon_84f4af8800d0459bab4f7da8f56435bd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7d8e22c3fe28534af85eb18d4a1d805f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31ec80d200f1ca639c4ffcb2da029eee = $(`&lt;div id=&quot;html_31ec80d200f1ca639c4ffcb2da029eee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_7d8e22c3fe28534af85eb18d4a1d805f.setContent(html_31ec80d200f1ca639c4ffcb2da029eee);
#
#
#
#         marker_03521bbe9ae2039149529c7158d770f8.bindPopup(popup_7d8e22c3fe28534af85eb18d4a1d805f)
#         ;
#
#
#
#
#                 marker_03521bbe9ae2039149529c7158d770f8.setIcon(icon_84f4af8800d0459bab4f7da8f56435bd);
#
#
#             var marke

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c76c410fef9a59482104ad8ab42dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c76c410fef9a59482104ad8ab42dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c76c410fef9a59482104ad8ab42dba = L.map(
#                 &quot;map_31c76c410fef9a59482104ad8ab42dba&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4072160df4854f3b18962a1af589f5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var circle_d528f2b0330bc2c56c0763c36865104d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_395e4d695d13d785be7064d07bbe9013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4559a128f785ce02bcbb48b93eff7c2 = $(`&lt;div id=&quot;html_b4559a128f785ce02bcbb48b93eff7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_395e4d695d13d785be7064d07bbe9013.setContent(html_b4559a128f785ce02bcbb48b93eff7c2);
#
#
#
#         circle_d528f2b0330bc2c56c0763c36865104d.bindPopup(popup_395e4d695d13d785be7064d07bbe9013)
#         ;
#
#
#
#
#             var marker_aaeceb29b5229d6a16ab2574fdd94fa3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_9b635235cb951842ff6b7a1c096c9efe = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# For each launch site, add a Circle object with its coordinate and an icon showing its name to the map
for index, site in launch_sites_df.iterrows():
    # Create a circle for each launch site
    circle = folium.Circle(
        [site['Lat'], site['Long']],
        radius=1000, # Set a radius of 1000m
        color='#000000', # Black color
        fill=True
    ).add_child(folium.Popup(site['Launch Site'])) # Add a popup with the launch site name

    # Create a marker for each launch site
    marker = folium.map.Marker(
        [site['Lat'], site['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site['Launch Site'],
        )
    )

    # Add the circle and marker to the map
    site_map.add_child(circle)
    site_map.add_child(marker)

# Display the map with all launch sites marked
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c76c410fef9a59482104ad8ab42dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c76c410fef9a59482104ad8ab42dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c76c410fef9a59482104ad8ab42dba = L.map(
#                 &quot;map_31c76c410fef9a59482104ad8ab42dba&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4072160df4854f3b18962a1af589f5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var circle_d528f2b0330bc2c56c0763c36865104d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_395e4d695d13d785be7064d07bbe9013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4559a128f785ce02bcbb48b93eff7c2 = $(`&lt;div id=&quot;html_b4559a128f785ce02bcbb48b93eff7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_395e4d695d13d785be7064d07bbe9013.setContent(html_b4559a128f785ce02bcbb48b93eff7c2);
#
#
#
#         circle_d528f2b0330bc2c56c0763c36865104d.bindPopup(popup_395e4d695d13d785be7064d07bbe9013)
#         ;
#
#
#
#
#             var marker_aaeceb29b5229d6a16ab2574fdd94fa3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_9b635235cb951842ff6b7a1c096c9efe = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             var circle_1c2cae847dfa203ffd6f5979f761103c = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_9b897e79705519cb5b7a857221e81e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a453e4c7868e8e7396c514055b96b7 = $(`&lt;div id=&quot;html_94a453e4c7868e8e7396c514055b96b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9b897e79705519cb5b7a857221e81e71.setContent(html_94a453e4c7868e8e7396c514055b96b7);
#
#
#
#         circle_1c2cae847dfa203ffd6f5979f761103c.bindPopup(popup_9b897e79705519cb5b7a857221e81e71)
#         ;
#
#
#
#
#             var marker_8bc2c7c8527d769e54d4955865f35a7e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_2c50180ea3a120f89a0c4fd77bd77aed = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u00

# %%
for index, site in launch_sites_df.iterrows():
    # Create a circle for each launch site with name and coordinates in the popup
    popup_html = f"{site['Launch Site']}<br>Lat: {site['Lat']:.4f}, Long: {site['Long']:.4f}"
    circle = folium.Circle(
        [site['Lat'], site['Long']],
        radius=1000, # Set a radius of 1000m
        color='#000000', # Black color
        fill=True
    ).add_child(folium.Popup(popup_html))

    # Create a marker for each launch site with a DivIcon showing its name
    marker = folium.map.Marker(
        [site['Lat'], site['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site['Launch Site'],
        )
    )

    # Add the circle and marker to the map
    site_map.add_child(circle)
    site_map.add_child(marker)

# Display the map with all launch sites marked
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c76c410fef9a59482104ad8ab42dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c76c410fef9a59482104ad8ab42dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c76c410fef9a59482104ad8ab42dba = L.map(
#                 &quot;map_31c76c410fef9a59482104ad8ab42dba&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4072160df4854f3b18962a1af589f5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var circle_d528f2b0330bc2c56c0763c36865104d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_395e4d695d13d785be7064d07bbe9013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4559a128f785ce02bcbb48b93eff7c2 = $(`&lt;div id=&quot;html_b4559a128f785ce02bcbb48b93eff7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_395e4d695d13d785be7064d07bbe9013.setContent(html_b4559a128f785ce02bcbb48b93eff7c2);
#
#
#
#         circle_d528f2b0330bc2c56c0763c36865104d.bindPopup(popup_395e4d695d13d785be7064d07bbe9013)
#         ;
#
#
#
#
#             var marker_aaeceb29b5229d6a16ab2574fdd94fa3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_9b635235cb951842ff6b7a1c096c9efe = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             var circle_1c2cae847dfa203ffd6f5979f761103c = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_9b897e79705519cb5b7a857221e81e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a453e4c7868e8e7396c514055b96b7 = $(`&lt;div id=&quot;html_94a453e4c7868e8e7396c514055b96b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9b897e79705519cb5b7a857221e81e71.setContent(html_94a453e4c7868e8e7396c514055b96b7);
#
#
#
#         circle_1c2cae847dfa203ffd6f5979f761103c.bindPopup(popup_9b897e79705519cb5b7a857221e81e71)
#         ;
#
#
#
#
#             var marker_8bc2c7c8527d769e54d4955865f35a7e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_2c50180ea3a120f89a0c4fd77bd77aed = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u00

# %% [markdown]
# Now, let's mark each launch attempt (successful or failed) on the map.

# %%
# Initialize a new map for launch outcomes, or use the existing site_map if preferred
# For clarity, let's re-initialize the map with the same NASA coordinates and zoom level as before
# so we can overlay the launch outcomes clearly.
# First, re-create the base map and the launch site markers from the previous steps

nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map_launches = folium.Map(location=nasa_coordinate, zoom_start=10)

# Add the NASA Johnson Space Center marker and circle again
circle_nasa = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker_nasa = folium.map.Marker(
    nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
    )
)
site_map_launches.add_child(circle_nasa)
site_map_launches.add_child(marker_nasa)

# Add the launch site markers with their circles again
for index, site in launch_sites_df.iterrows():
    popup_html = f"{site['Launch Site']}<br>Lat: {site['Lat']:.4f}, Long: {site['Long']:.4f}"
    circle = folium.Circle(
        [site['Lat'], site['Long']],
        radius=1000,
        color='#000000',
        fill=True
    ).add_child(folium.Popup(popup_html))
    marker = folium.map.Marker(
        [site['Lat'], site['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site['Launch Site'],
        )
    )
    site_map_launches.add_child(circle)
    site_map_launches.add_child(marker)


# For each launch, add a CircleMarker to the map
# Marker for successful launches (class=1) will be green
# Marker for failed launches (class=0) will be red
for index, record in spacex_df.iterrows():
    coordinate = [record['Lat'], record['Long']]
    if record['class'] == 1:
        color = 'green'
        outcome = 'Success'
    else:
        color = 'red'
        outcome = 'Failure'

    # Create a CircleMarker for each launch outcome
    folium.CircleMarker(
        coordinate,
        radius=5, # Small radius for individual launches
        color=color,
        fill=True,
        fill_color=color,
        fill_opacity=0.7,
        popup=f"Launch Site: {record['Launch Site']}<br>Outcome: {outcome}"
    ).add_to(site_map_launches)

# Display the map with launch outcomes
site_map_launches
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6396dc389e8d28ea25a5f506d291653d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6396dc389e8d28ea25a5f506d291653d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6396dc389e8d28ea25a5f506d291653d = L.map(
#                 &quot;map_6396dc389e8d28ea25a5f506d291653d&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaa913fedb8c433fc0849396a0510ba3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aaa913fedb8c433fc0849396a0510ba3.addTo(map_6396dc389e8d28ea25a5f506d291653d);
#
#
#             var circle_53a6a80022dff3dc2d51c04c91c1d5dc = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6396dc389e8d28ea25a5f506d291653d);
#
#
#         var popup_fc494c52d42f29d365a7fad36ac5eff8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da97f0ce2b7988c4301424ca74452f9a = $(`&lt;div id=&quot;html_da97f0ce2b7988c4301424ca74452f9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_fc494c52d42f29d365a7fad36ac5eff8.setContent(html_da97f0ce2b7988c4301424ca74452f9a);
#
#
#
#         circle_53a6a80022dff3dc2d51c04c91c1d5dc.bindPopup(popup_fc494c52d42f29d365a7fad36ac5eff8)
#         ;
#
#
#
#
#             var marker_33fbd7b0986f327044574e3d6f364186 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_6396dc389e8d28ea25a5f506d291653d);
#
#
#             var div_icon_eacb1061e342fe047a349043260743e6 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_33fbd7b0986f327044574e3d6f364186.setIcon(div_icon_eacb1061e342fe047a349043260743e6);
#
#
#             var circle_08c24c348a37c7eedc9fad5239ec29e5 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6396dc389e8d28ea25a5f506d291653d);
#
#
#         var popup_8b47d0ed99edc8a11d3addd0b14a756f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fa63d6d0126315d1ffbfd2470416634 = $(`&lt;div id=&quot;html_4fa63d6d0126315d1ffbfd2470416634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;br&gt;Lat: 28.5623, Long: -80.5774&lt;/div&gt;`)[0];
#                 popup_8b47d0ed99edc8a11d3addd0b14a756f.setContent(html_4fa63d6d0126315d1ffbfd2470416634);
#
#
#
#         circle_08c24c348a37c7eedc9fad5239ec29e5.bindPopup(popup_8b47d0ed99edc8a11d3addd0b14a756f)
#         ;
#
#
#
#
#             var marker_a8b4faa7f281f746bad5feccce687d8e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_6396dc389e8d28ea25a5f506d291653d);
#
#
#             var div_icon_284bc1764dc5328009c84911ab35ee92 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker

# %% [markdown]
# yes they are all close to the cost and ecuater

# %%
Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates. Recall that data frame spacex_df has detailed launch records, and the class column indicates if this launch was successful or not

# %% [markdown]
# To determine which sites have high success rates, we'll calculate the success rate (number of successful launches / total launches) for each launch site.

# %%
# Calculate the number of successful (class=1) and failed (class=0) launches per site
success_counts = spacex_df[spacex_df['class'] == 1].groupby('Launch Site').size().reset_index(name='Successful Launches')
failure_counts = spacex_df[spacex_df['class'] == 0].groupby('Launch Site').size().reset_index(name='Failed Launches')
total_counts = spacex_df.groupby('Launch Site').size().reset_index(name='Total Launches')

# Merge these counts with launch_sites_df
launch_sites_stats = pd.merge(launch_sites_df, total_counts, on='Launch Site', how='left')
launch_sites_stats = pd.merge(launch_sites_stats, success_counts, on='Launch Site', how='left').fillna(0) # Fill NaN for sites with no successes
launch_sites_stats = pd.merge(launch_sites_stats, failure_counts, on='Launch Site', how='left').fillna(0) # Fill NaN for sites with no failures

# Calculate success rate
launch_sites_stats['Success Rate'] = (launch_sites_stats['Successful Launches'] / launch_sites_stats['Total Launches']) * 100

display(launch_sites_stats)
# Out:
#     Launch Site        Lat        Long  Total Launches  Successful Launches  \
# 0   CCAFS LC-40  28.562302  -80.577356              26                    7
# 1  CCAFS SLC-40  28.563197  -80.576820               7                    3
# 2    KSC LC-39A  28.573255  -80.646895              13                   10
# 3   VAFB SLC-4E  34.632834 -120.610745              10                    4
#
#    Failed Launches  Success Rate
# 0               19     26.923077
# 1                4     42.857143
# 2                3     76.923077
# 3                6     40.000000

# %% [markdown]
# Now, let's create a new map (or re-initialize the existing `site_map`) and add markers for each launch site, displaying their calculated success rates.

# %%
# Re-initialize the map to remove previous launch outcome markers, keeping only site markers updated with success rates
site_map_success_rate = folium.Map(location=nasa_coordinate, zoom_start=10)

# Add the NASA Johnson Space Center marker and circle again
circle_nasa = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker_nasa = folium.map.Marker(
    nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
    )
)
site_map_success_rate.add_child(circle_nasa)
site_map_success_rate.add_child(marker_nasa)


# For each launch site, add a Circle object and a DivIcon marker showing its name and success rate
for index, site in launch_sites_stats.iterrows():
    # Create a popup with the launch site name, coordinates, and success rate
    popup_html = f"{site['Launch Site']}<br>Lat: {site['Lat']:.4f}, Long: {site['Long']:.4f}<br>Success Rate: {site['Success Rate']:.2f}%"
    circle = folium.Circle(
        [site['Lat'], site['Long']],
        radius=1000, # Set a radius of 1000m
        color='#000000', # Black color
        fill=True
    ).add_child(folium.Popup(popup_html))

    # Create a marker with DivIcon showing site name and success rate
    marker_html = f"<div style='font-size: 12px; color:#d35400;'><b>{site['Launch Site']}</b><br>{site['Success Rate']:.0f}%</div>"
    marker = folium.map.Marker(
        [site['Lat'], site['Long']],
        icon=DivIcon(
            icon_size=(100,30),
            icon_anchor=(0,0),
            html=marker_html,
        )
    )

    # Add the circle and marker to the map
    site_map_success_rate.add_child(circle)
    site_map_success_rate.add_child(marker)

# Display the map with launch site success rates
site_map_success_rate
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f261ff073fda70edb92fbaddbed7da5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f261ff073fda70edb92fbaddbed7da5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f261ff073fda70edb92fbaddbed7da5f = L.map(
#                 &quot;map_f261ff073fda70edb92fbaddbed7da5f&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_643bea872df185b179f1f89d761362ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_643bea872df185b179f1f89d761362ec.addTo(map_f261ff073fda70edb92fbaddbed7da5f);
#
#
#             var circle_e5e7be835aa1752a9255cb900cdd1ccf = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f261ff073fda70edb92fbaddbed7da5f);
#
#
#         var popup_f03b8fa234a71936e78abc0ea999b0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad0e72ad4b660119be0421d992c58236 = $(`&lt;div id=&quot;html_ad0e72ad4b660119be0421d992c58236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_f03b8fa234a71936e78abc0ea999b0f6.setContent(html_ad0e72ad4b660119be0421d992c58236);
#
#
#
#         circle_e5e7be835aa1752a9255cb900cdd1ccf.bindPopup(popup_f03b8fa234a71936e78abc0ea999b0f6)
#         ;
#
#
#
#
#             var marker_1eaac042b77925719c5a3e772899c763 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_f261ff073fda70edb92fbaddbed7da5f);
#
#
#             var div_icon_f6fea04f11741b8d7ad3f3c12d201469 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_1eaac042b77925719c5a3e772899c763.setIcon(div_icon_f6fea04f11741b8d7ad3f3c12d201469);
#
#
#             var circle_c4a17096fd3007065ffd399fa98b25b6 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f261ff073fda70edb92fbaddbed7da5f);
#
#
#         var popup_aeb7a5cd049b57413f0bd52df9a0f3ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc1cc145b09d765b73ab7904d518c6c0 = $(`&lt;div id=&quot;html_fc1cc145b09d765b73ab7904d518c6c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;br&gt;Lat: 28.5623, Long: -80.5774&lt;br&gt;Success Rate: 26.92%&lt;/div&gt;`)[0];
#                 popup_aeb7a5cd049b57413f0bd52df9a0f3ac.setContent(html_fc1cc145b09d765b73ab7904d518c6c0);
#
#
#
#         circle_c4a17096fd3007065ffd399fa98b25b6.bindPopup(popup_aeb7a5cd049b57413f0bd52df9a0f3ac)
#         ;
#
#
#
#
#             var marker_af213c8c8bc043d026fb93721e3912e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_f261ff073fda70edb92fbaddbed7da5f);
#
#
#             var div_icon_d6e71851e66bfd6b1db837534c4a5373 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\u0027font-size: 12px; color:#d35400;\u0027\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003cbr\u003e27%\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [100, 30],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty

# %% [markdown]
# Let's define a function to assign a color based on the `class` column (success or failure) and then visualize individual launch outcomes on the map.

# %%
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'

# Create a new map object, or use the existing `site_map` if you want to overlay
# For clarity, let's re-initialize a map similar to `site_map_launches` but using the function for colors

# Re-initialize the map to show individual launch outcomes with colored markers
site_map_outcomes = folium.Map(location=nasa_coordinate, zoom_start=10)

# Add the NASA Johnson Space Center marker and circle again
circle_nasa = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker_nasa = folium.map.Marker(
    nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
    )
)
site_map_outcomes.add_child(circle_nasa)
site_map_outcomes.add_child(marker_nasa)

# Add the launch site markers with their circles again (without success rates for this view, focusing on individual outcomes)
for index, site in launch_sites_df.iterrows():
    popup_html = f"{site['Launch Site']}<br>Lat: {site['Lat']:.4f}, Long: {site['Long']:.4f}"
    circle = folium.Circle(
        [site['Lat'], site['Long']],
        radius=1000,
        color='#000000',
        fill=True
    ).add_child(folium.Popup(popup_html))
    marker = folium.map.Marker(
        [site['Lat'], site['Long']],
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site['Launch Site'],
        )
    )
    site_map_outcomes.add_child(circle)
    site_map_outcomes.add_child(marker)


# Apply the function to each row of spacex_df to get the marker color
for index, record in spacex_df.iterrows():
    marker_color = assign_marker_color(record['class'])
    coordinate = [record['Lat'], record['Long']]
    outcome = 'Success' if record['class'] == 1 else 'Failure'

    # Create a CircleMarker for each launch outcome
    folium.CircleMarker(
        coordinate,
        radius=5, # Small radius for individual launches
        color=marker_color,
        fill=True,
        fill_color=marker_color,
        fill_opacity=0.7,
        popup=f"Launch Site: {record['Launch Site']}<br>Outcome: {outcome}"
    ).add_to(site_map_outcomes)

# Display the map with launch outcomes colored by success/failure
site_map_outcomes
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4d143838cec3113153f23a0a40f9e8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4d143838cec3113153f23a0a40f9e8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4d143838cec3113153f23a0a40f9e8e = L.map(
#                 &quot;map_b4d143838cec3113153f23a0a40f9e8e&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0b2383c5e93335c11b5faba2ab068e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0b2383c5e93335c11b5faba2ab068e0.addTo(map_b4d143838cec3113153f23a0a40f9e8e);
#
#
#             var circle_a378afe62b4de66264c259ec6e13cea6 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b4d143838cec3113153f23a0a40f9e8e);
#
#
#         var popup_671e7c661b8e7e0b73f25af5772d697d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ea8dd7df4bd1122236911ccac27b852 = $(`&lt;div id=&quot;html_4ea8dd7df4bd1122236911ccac27b852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_671e7c661b8e7e0b73f25af5772d697d.setContent(html_4ea8dd7df4bd1122236911ccac27b852);
#
#
#
#         circle_a378afe62b4de66264c259ec6e13cea6.bindPopup(popup_671e7c661b8e7e0b73f25af5772d697d)
#         ;
#
#
#
#
#             var marker_ca198b509071cdcbb7394806501c751f = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_b4d143838cec3113153f23a0a40f9e8e);
#
#
#             var div_icon_50a55a3927dc2bceea1612fd07a24429 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_ca198b509071cdcbb7394806501c751f.setIcon(div_icon_50a55a3927dc2bceea1612fd07a24429);
#
#
#             var circle_ad52cd15b9b2d569f8e391cc767ff3e2 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b4d143838cec3113153f23a0a40f9e8e);
#
#
#         var popup_11c69e64f30332504ed597b7fbcabca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d8c3cff6338360caf4606ca2d054b2f = $(`&lt;div id=&quot;html_3d8c3cff6338360caf4606ca2d054b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;br&gt;Lat: 28.5623, Long: -80.5774&lt;/div&gt;`)[0];
#                 popup_11c69e64f30332504ed597b7fbcabca5.setContent(html_3d8c3cff6338360caf4606ca2d054b2f);
#
#
#
#         circle_ad52cd15b9b2d569f8e391cc767ff3e2.bindPopup(popup_11c69e64f30332504ed597b7fbcabca5)
#         ;
#
#
#
#
#             var marker_8b1e57107ce2671d30e7579a1234e1c6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_b4d143838cec3113153f23a0a40f9e8e);
#
#
#             var div_icon_ff2551f0a12f3e3c377c1e234510e871 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker

# %% [markdown]
# ## Calculate Distances to Proximities
#
# To understand the geographical context of the launch sites, we can calculate the distance from each launch site to various proximity points such as coastlines, highways, or cities. For this example, we will demonstrate with the `CCAFS LC-40` launch site and a few hypothetical proximity points.

# %%
get_ipython().system('pip install geopy')
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.1)

# %%
from geopy.distance import geodesic

def calculate_distance(lat1, lon1, lat2, lon2):
    """Calculates the geodesic distance between two points in kilometers."""
    point1 = (lat1, lon1)
    point2 = (lat2, lon2)
    return geodesic(point1, point2).km

# %% [markdown]
# Let's define some hypothetical proximity points for `CCAFS LC-40` (the first launch site in our `launch_sites_df`) to demonstrate the distance calculation. We'll pick a coastal point, a highway point, and a city center nearby.

# %%
# Get coordinates for CCAFS LC-40
ccafs_lc40 = launch_sites_df[launch_sites_df['Launch Site'] == 'CCAFS LC-40'].iloc[0]
ccafs_lat = ccafs_lc40['Lat']
ccafs_lon = ccafs_lc40['Long']

# Define hypothetical proximity points
proximity_points = {
    'Coastline': {'lat': 28.560, 'lon': -80.560}, # Slightly east into the water
    'Highway (US-1)': {'lat': 28.570, 'lon': -80.800}, # Near Titusville
    'City Center (Titusville)': {'lat': 28.618, 'lon': -80.824} # Approximate center of Titusville
}

distances = {}
for name, coords in proximity_points.items():
    dist = calculate_distance(ccafs_lat, ccafs_lon, coords['lat'], coords['lon'])
    distances[name] = dist
    print(f"Distance from CCAFS LC-40 to {name}: {dist:.2f} km")
# Out:
# Distance from CCAFS LC-40 to Coastline: 1.72 km
# Distance from CCAFS LC-40 to Highway (US-1): 21.80 km
# Distance from CCAFS LC-40 to City Center (Titusville): 24.90 km

# %% [markdown]
# Now, let's visualize these distances on a map by drawing lines from the `CCAFS LC-40` launch site to each of the defined proximity points.

# %%
# Create a new map centered around CCAFS LC-40
site_map_distances = folium.Map(location=[ccafs_lat, ccafs_lon], zoom_start=11)

# Add marker for CCAFS LC-40
folium.Marker(
    [ccafs_lat, ccafs_lon],
    popup='CCAFS LC-40',
    icon=folium.Icon(color='blue', icon='rocket')
).add_to(site_map_distances)

# Add markers for proximity points and draw lines
for name, coords in proximity_points.items():
    folium.Marker(
        [coords['lat'], coords['lon']],
        popup=f"{name} ({distances[name]:.2f} km)",
        icon=folium.Icon(color='purple', icon='info-sign')
    ).add_to(site_map_distances)

    # Draw a line between the launch site and the proximity point
    folium.PolyLine(
        locations=[[ccafs_lat, ccafs_lon], [coords['lat'], coords['lon']]],
        color='red',
        weight=2.5,
        opacity=1
    ).add_to(site_map_distances)

# Display the map
site_map_distances
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b445c770df8dc3bb58dda6efa1675bea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b445c770df8dc3bb58dda6efa1675bea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b445c770df8dc3bb58dda6efa1675bea = L.map(
#                 &quot;map_b445c770df8dc3bb58dda6efa1675bea&quot;,
#                 {
#                     center: [28.56230197, -80.57735648],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55bf9f524a841c3ad230eb5e909a6d49 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55bf9f524a841c3ad230eb5e909a6d49.addTo(map_b445c770df8dc3bb58dda6efa1675bea);
#
#
#             var marker_ad6bc45f9a87a71b9be9ce28f0d0b027 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_b445c770df8dc3bb58dda6efa1675bea);
#
#
#             var icon_6c84e45cae84474060d4c280a81d406e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_86a308dab18cec34aa6842fe96407204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec84ca21f840adcc3baee7e928674322 = $(`&lt;div id=&quot;html_ec84ca21f840adcc3baee7e928674322&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_86a308dab18cec34aa6842fe96407204.setContent(html_ec84ca21f840adcc3baee7e928674322);
#
#
#
#         marker_ad6bc45f9a87a71b9be9ce28f0d0b027.bindPopup(popup_86a308dab18cec34aa6842fe96407204)
#         ;
#
#
#
#
#                 marker_ad6bc45f9a87a71b9be9ce28f0d0b027.setIcon(icon_6c84e45cae84474060d4c280a81d406e);
#
#
#             var marker_fd208649a71b220b94dce9528d5d910b = L.marker(
#                 [28.56, -80.56],
#                 {
# }
#             ).addTo(map_b445c770df8dc3bb58dda6efa1675bea);
#
#
#             var icon_e1225138b14bff5f40a3d1646e3a5e1f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7f3c08b3a61021d8a14e735a300f6409 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04c650f82acc68f76d20c73d12c34964 = $(`&lt;div id=&quot;html_04c650f82acc68f76d20c73d12c34964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coastline (1.72 km)&lt;/div&gt;`)[0];
#                 popup_7f3c08b3a61021d8a14e735a300f6409.setContent(html_04c650f82acc68f76d20c73d12c34964);
#
#
#
#         marker_fd208649a71b220b94dce9528d5d910b.bindPopup(popup_7f3c08b3a61021d8a14e735a300f6409)
#         ;
#
#
#
#
#                 marker_fd208649a71b220b94dce9528d5d910b.setIcon(icon_e1225138b14bff5f40a3d1646e3a5e1f);
#
#
#             var poly_line_fe6399d47fc5fabc9b4a00e5e8b68b54 = L.polyline(
#                 [[28.56230197, -80.57735648], [28.56, -80.56]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_b445c770df8dc3bb58dda6efa1675bea);
#
#
#             var marker_65f2ed31859cd66357e5679c0267ea88 = L.marker(
#                 [28.57, -80.8],
#                 {
# }
#             ).addTo(map_b445c770df8dc3bb58dda6efa1675bea);
#
#
#             var icon_f71fa7ca0affcb1a5638869bb4da9a2c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_36eff45c022bd5f96308cac22ca46246

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c76c410fef9a59482104ad8ab42dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c76c410fef9a59482104ad8ab42dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c76c410fef9a59482104ad8ab42dba = L.map(
#                 &quot;map_31c76c410fef9a59482104ad8ab42dba&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4072160df4854f3b18962a1af589f5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var circle_d528f2b0330bc2c56c0763c36865104d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_395e4d695d13d785be7064d07bbe9013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4559a128f785ce02bcbb48b93eff7c2 = $(`&lt;div id=&quot;html_b4559a128f785ce02bcbb48b93eff7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_395e4d695d13d785be7064d07bbe9013.setContent(html_b4559a128f785ce02bcbb48b93eff7c2);
#
#
#
#         circle_d528f2b0330bc2c56c0763c36865104d.bindPopup(popup_395e4d695d13d785be7064d07bbe9013)
#         ;
#
#
#
#
#             var marker_aaeceb29b5229d6a16ab2574fdd94fa3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_9b635235cb951842ff6b7a1c096c9efe = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             var circle_1c2cae847dfa203ffd6f5979f761103c = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_9b897e79705519cb5b7a857221e81e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a453e4c7868e8e7396c514055b96b7 = $(`&lt;div id=&quot;html_94a453e4c7868e8e7396c514055b96b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9b897e79705519cb5b7a857221e81e71.setContent(html_94a453e4c7868e8e7396c514055b96b7);
#
#
#
#         circle_1c2cae847dfa203ffd6f5979f761103c.bindPopup(popup_9b897e79705519cb5b7a857221e81e71)
#         ;
#
#
#
#
#             var marker_8bc2c7c8527d769e54d4955865f35a7e = L.marker(
#                 [

# %% [markdown]
# ### Visualizing Distances on `site_map` with `folium.PolyLine`
#
# Based on your request, I'll now add `folium.PolyLine` objects to the `site_map` to connect each launch site with its corresponding closest coastline point. This will visually represent the calculated distances directly on the map.

# %%
# Iterate through the coastline_df to get each launch site and its closest coastline point
for index, row in coastline_df.iterrows():
    # Define the coordinates for the PolyLine
    coordinates = [[row['Site Lat'], row['Site Lon']], [row['Coastline Lat'], row['Coastline Lon']]]

    # Create a folium.PolyLine object
    lines = folium.PolyLine(
        locations=coordinates,
        color='blue',  # Choose a color for the line
        weight=2,      # Set the line thickness
        opacity=0.7    # Set the transparency
    )

    # Add the PolyLine to the site_map
    site_map.add_child(lines)

# Display the updated site_map with PolyLines
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c76c410fef9a59482104ad8ab42dba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c76c410fef9a59482104ad8ab42dba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c76c410fef9a59482104ad8ab42dba = L.map(
#                 &quot;map_31c76c410fef9a59482104ad8ab42dba&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4072160df4854f3b18962a1af589f5d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var circle_d528f2b0330bc2c56c0763c36865104d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_395e4d695d13d785be7064d07bbe9013 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4559a128f785ce02bcbb48b93eff7c2 = $(`&lt;div id=&quot;html_b4559a128f785ce02bcbb48b93eff7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_395e4d695d13d785be7064d07bbe9013.setContent(html_b4559a128f785ce02bcbb48b93eff7c2);
#
#
#
#         circle_d528f2b0330bc2c56c0763c36865104d.bindPopup(popup_395e4d695d13d785be7064d07bbe9013)
#         ;
#
#
#
#
#             var marker_aaeceb29b5229d6a16ab2574fdd94fa3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#             var div_icon_9b635235cb951842ff6b7a1c096c9efe = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             tile_layer_4072160df4854f3b18962a1af589f5d0.addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#                 marker_aaeceb29b5229d6a16ab2574fdd94fa3.setIcon(div_icon_9b635235cb951842ff6b7a1c096c9efe);
#
#
#             var circle_1c2cae847dfa203ffd6f5979f761103c = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_31c76c410fef9a59482104ad8ab42dba);
#
#
#         var popup_9b897e79705519cb5b7a857221e81e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a453e4c7868e8e7396c514055b96b7 = $(`&lt;div id=&quot;html_94a453e4c7868e8e7396c514055b96b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_9b897e79705519cb5b7a857221e81e71.setContent(html_94a453e4c7868e8e7396c514055b96b7);
#
#
#
#         circle_1c2cae847dfa203ffd6f5979f761103c.bindPopup(popup_9b897e79705519cb5b7a857221e81e71)
#         ;
#
#
#
#
#             var marker_8bc2c7c8527d769e54d4955865f35a7e = L.marker(
#                 [

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# ### Identifying Closest Coastline Coordinates and Calculating Distances for all Launch Sites
#
# To programmatically find a 'closest coastline' point for each launch site, we will make a simplifying assumption: we'll define a point slightly east (for Florida sites) or west (for California site) of the launch site as its closest coastline. We'll then calculate the distance to this point.

# %%
coastline_data = []
longitude_offset = 0.015 # Degrees to shift longitude to simulate coastline

for index, site in launch_sites_df.iterrows():
    site_name = site['Launch Site']
    site_lat = site['Lat']
    site_lon = site['Long']

    # Determine coastline direction based on launch site name
    if 'CCAFS' in site_name or 'KSC' in site_name: # Florida sites, coastline to the East
        coastline_lon = site_lon + longitude_offset
    elif 'VAFB' in site_name: # California site, coastline to the West
        coastline_lon = site_lon - longitude_offset
    else:
        coastline_lon = site_lon # Default if unknown

    coastline_lat = site_lat # Assume coastline is at the same latitude for simplicity

    distance = calculate_distance(site_lat, site_lon, coastline_lat, coastline_lon)

    coastline_data.append({
        'Launch Site': site_name,
        'Site Lat': site_lat,
        'Site Lon': site_lon,
        'Coastline Lat': coastline_lat,
        'Coastline Lon': coastline_lon,
        'Distance to Coastline (km)': distance
    })

coastline_df = pd.DataFrame(coastline_data)
display(coastline_df)
# Out:
#     Launch Site   Site Lat    Site Lon  Coastline Lat  Coastline Lon  \
# 0   CCAFS LC-40  28.562302  -80.577356      28.562302     -80.562356
# 1  CCAFS SLC-40  28.563197  -80.576820      28.563197     -80.561820
# 2    KSC LC-39A  28.573255  -80.646895      28.573255     -80.631895
# 3   VAFB SLC-4E  34.632834 -120.610745      34.632834    -120.625745
#
#    Distance to Coastline (km)
# 0                    1.465394
# 1                    1.465381
# 2                    1.465241
# 3                    1.372817

# %% [markdown]
# ### Visualizing Distances to Closest Coastline for all Launch Sites
#
# Now, let's plot these launch sites and their corresponding 'closest coastline' points on a map, connected by lines, to visually represent the calculated distances.

# %%
# Re-initialize a map, centered around the mean of all launch sites for a good overview
map_coastlines = folium.Map(location=[spacex_df['Lat'].mean(), spacex_df['Long'].mean()], zoom_start=6)

# Add the NASA Johnson Space Center marker and circle (from previous steps)
circle_nasa = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker_nasa = folium.map.Marker(
    nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
    )
)
map_coastlines.add_child(circle_nasa)
map_coastlines.add_child(marker_nasa)


for index, row in coastline_df.iterrows():
    # Add marker for the launch site
    folium.Marker(
        [row['Site Lat'], row['Site Lon']],
        popup=f"{row['Launch Site']}",
        icon=folium.Icon(color='blue', icon='rocket')
    ).add_to(map_coastlines)

    # Add marker for the closest coastline point
    folium.Marker(
        [row['Coastline Lat'], row['Coastline Lon']],
        popup=f"Coastline ({row['Distance to Coastline (km)']:.2f} km)",
        icon=folium.Icon(color='green', icon='info-sign')
    ).add_to(map_coastlines)

    # Draw a line between the launch site and the coastline point
    folium.PolyLine(
        locations=[[row['Site Lat'], row['Site Lon']], [row['Coastline Lat'], row['Coastline Lon']]],
        color='red',
        weight=2.5,
        opacity=1
    ).add_to(map_coastlines)

# Display the map
map_coastlines
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daae79e047f562d3d665fdac622c80b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daae79e047f562d3d665fdac622c80b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daae79e047f562d3d665fdac622c80b2 = L.map(
#                 &quot;map_daae79e047f562d3d665fdac622c80b2&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0e9bc865ceab24849a1104cbc5655ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0e9bc865ceab24849a1104cbc5655ac.addTo(map_daae79e047f562d3d665fdac622c80b2);
#
#
#             var circle_1abcdc0763239f8a83b6ae762385299a = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_daae79e047f562d3d665fdac622c80b2);
#
#
#         var popup_41458d569714ff3dda0e0563f0264206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d6ce884e8d46bb37ec83e5f55cadfd3 = $(`&lt;div id=&quot;html_2d6ce884e8d46bb37ec83e5f55cadfd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_41458d569714ff3dda0e0563f0264206.setContent(html_2d6ce884e8d46bb37ec83e5f55cadfd3);
#
#
#
#         circle_1abcdc0763239f8a83b6ae762385299a.bindPopup(popup_41458d569714ff3dda0e0563f0264206)
#         ;
#
#
#
#
#             var marker_9c7cf50b22f7da8b11560859157e2879 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_daae79e047f562d3d665fdac622c80b2);
#
#
#             var div_icon_f3a6216959a7984cf1a73d49ba1121b7 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_9c7cf50b22f7da8b11560859157e2879.setIcon(div_icon_f3a6216959a7984cf1a73d49ba1121b7);
#
#
#             var marker_8d4914004b52fcafc67a3e68209af2e7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_daae79e047f562d3d665fdac622c80b2);
#
#
#             var icon_66f2e46ebc3b5787fb7d5e14e4d88c04 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_25e553d341f2a29b1fb96321c0dff06e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99481b9e1d4af5c032783f0c783730ce = $(`&lt;div id=&quot;html_99481b9e1d4af5c032783f0c783730ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_25e553d341f2a29b1fb96321c0dff06e.setContent(html_99481b9e1d4af5c032783f0c783730ce);
#
#
#
#         marker_8d4914004b52fcafc67a3e68209af2e7.bindPopup(popup_25e553d341f2a29b1fb96321c0dff06e)
#         ;
#
#
#
#
#                 marker_8d4914004b52fcafc67a3e68209af2e7.setIcon(icon_66f2e46ebc3b5787fb7d5e14e4d88c04);
#
#
#             var marker_08c1e52da312ea7af581449a581534e9 = L.marker(
#                 [28.56230197, -80.56235648],
#                 {
# }
#             ).addTo(map_daae79e047f562d3d665fdac622c80b2);
#
#
#             var icon_840e81a3bd6d10d12ba950782f8ce4a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_cd17897a2084f0c5d5b

# %% [markdown]
# ### Identifying Closest City, Railway, and Highway Proximities for all Launch Sites
#
# Similar to the coastline, we'll define hypothetical closest points for cities, railways, and highways for each launch site and calculate their distances. These are illustrative points to demonstrate the functionality.

# %%
proximities_data = []

# Define offsets for hypothetical city, railway, highway points relative to each launch site
# These are simplified and illustrative offsets.

# For Florida sites (CCAFS LC-40, CCAFS SLC-40, KSC LC-39A)
florida_offsets = {
    'City': {'lat_offset': 0.05, 'lon_offset': -0.2}, # Northwest towards Titusville/Cocoa
    'Railway': {'lat_offset': 0.03, 'lon_offset': -0.15}, # Slightly west
    'Highway': {'lat_offset': -0.02, 'lon_offset': -0.1} # Slightly southwest
}

# For California site (VAFB SLC-4E)
california_offsets = {
    'City': {'lat_offset': 0.08, 'lon_offset': 0.1}, # Northeast towards Lompoc/Santa Maria
    'Railway': {'lat_offset': 0.04, 'lon_offset': 0.05}, # North-northeast
    'Highway': {'lat_offset': 0.02, 'lon_offset': 0.07} # East-northeast
}

for index, site in launch_sites_df.iterrows():
    site_name = site['Launch Site']
    site_lat = site['Lat']
    site_lon = site['Long']

    offsets = {}
    if 'CCAFS' in site_name or 'KSC' in site_name:
        offsets = florida_offsets
    elif 'VAFB' in site_name:
        offsets = california_offsets

    for prox_type, offset_vals in offsets.items():
        prox_lat = site_lat + offset_vals['lat_offset']
        prox_lon = site_lon + offset_vals['lon_offset']

        distance = calculate_distance(site_lat, site_lon, prox_lat, prox_lon)

        proximities_data.append({
            'Launch Site': site_name,
            'Site Lat': site_lat,
            'Site Lon': site_lon,
            'Proximity Type': prox_type,
            'Proximity Lat': prox_lat,
            'Proximity Lon': prox_lon,
            'Distance (km)': distance
        })

proximities_df = pd.DataFrame(proximities_data)
display(proximities_df)
# Out:
#      Launch Site   Site Lat    Site Lon Proximity Type  Proximity Lat  \
# 0    CCAFS LC-40  28.562302  -80.577356           City      28.612302
# 1    CCAFS LC-40  28.562302  -80.577356        Railway      28.592302
# 2    CCAFS LC-40  28.562302  -80.577356        Highway      28.542302
# 3   CCAFS SLC-40  28.563197  -80.576820           City      28.613197
# 4   CCAFS SLC-40  28.563197  -80.576820        Railway      28.593197
# 5   CCAFS SLC-40  28.563197  -80.576820        Highway      28.543197
# 6     KSC LC-39A  28.573255  -80.646895           City      28.623255
# 7     KSC LC-39A  28.573255  -80.646895        Railway      28.603255
# 8     KSC LC-39A  28.573255  -80.646895        Highway      28.553255
# 9    VAFB SLC-4E  34.632834 -120.610745           City      34.712834
# 10   VAFB SLC-4E  34.632834 -120.610745        Railway      34.672834
# 11   VAFB SLC-4E  34.632834 -120.610745        Highway      34.652834
#
#     Proximity Lon  Distance (km)
# 0      -80.777356      20.310215
# 1      -80.727356      15.027025
# 2      -80.677356      10.020280
# 3      -80.776820      20.310055
# 4      -80.726820      15.026903
# 5      -80.676820      10.020199
# 6      -80.846895      20.308258
# 7      -80.796895      15.025537
# 8      -80.746895      10.019289
# 9     -120.510745      12.761723
# 10    -120.560745       6.381654
# 11    -120.540745       6.780995

# %% [markdown]
# ### Visualizing Distances to City, Railway, and Highway for all Launch Sites
#
# Now, let's visualize these hypothetical proximity points for all launch sites on a new map, connecting them with lines.

# %%
# Re-initialize a map, centered around the mean of all launch sites for a good overview
map_proximities = folium.Map(location=[spacex_df['Lat'].mean(), spacex_df['Long'].mean()], zoom_start=6)

# Add the NASA Johnson Space Center marker and circle (from previous steps)
circle_nasa = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker_nasa = folium.map.Marker(
    nasa_coordinate,
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
    )
)
map_proximities.add_child(circle_nasa)
map_proximities.add_child(marker_nasa)


# Define colors for different proximity types
proximity_colors = {
    'City': 'red',
    'Railway': 'purple',
    'Highway': 'orange'
}

for index, row in proximities_df.iterrows():
    # Add marker for the launch site (only once per site, but safe to re-add if unique)
    folium.Marker(
        [row['Site Lat'], row['Site Lon']],
        popup=f"{row['Launch Site']}",
        icon=folium.Icon(color='blue', icon='rocket')
    ).add_to(map_proximities)

    # Add marker for the proximity point
    folium.Marker(
        [row['Proximity Lat'], row['Proximity Lon']],
        popup=f"{row['Proximity Type']} ({row['Distance (km)']:.2f} km)",
        icon=folium.Icon(color=proximity_colors.get(row['Proximity Type'], 'gray'), icon='info-sign')
    ).add_to(map_proximities)

    # Draw a line between the launch site and the proximity point
    folium.PolyLine(
        locations=[[row['Site Lat'], row['Site Lon']], [row['Proximity Lat'], row['Proximity Lon']]],
        color=proximity_colors.get(row['Proximity Type'], 'gray'),
        weight=2.5,
        opacity=1
    ).add_to(map_proximities)

# Display the map
map_proximities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d72d1bd288613c95ebb2cbe5dee1fae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d72d1bd288613c95ebb2cbe5dee1fae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d72d1bd288613c95ebb2cbe5dee1fae = L.map(
#                 &quot;map_4d72d1bd288613c95ebb2cbe5dee1fae&quot;,
#                 {
#                     center: [29.648980044464285, -87.74225182964287],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7799a9fc8d7820b313c041e5864e3e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7799a9fc8d7820b313c041e5864e3e5.addTo(map_4d72d1bd288613c95ebb2cbe5dee1fae);
#
#
#             var circle_5bb75197ae2abb626c9ba32e50626787 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d72d1bd288613c95ebb2cbe5dee1fae);
#
#
#         var popup_7ad074570104d1e4d5c0fa6deb858181 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af305fc02c8a21bd6f9cf7f1b37b605c = $(`&lt;div id=&quot;html_af305fc02c8a21bd6f9cf7f1b37b605c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_7ad074570104d1e4d5c0fa6deb858181.setContent(html_af305fc02c8a21bd6f9cf7f1b37b605c);
#
#
#
#         circle_5bb75197ae2abb626c9ba32e50626787.bindPopup(popup_7ad074570104d1e4d5c0fa6deb858181)
#         ;
#
#
#
#
#             var marker_dfa90f35c1f891c2aaaa04941ed9c929 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_4d72d1bd288613c95ebb2cbe5dee1fae);
#
#
#             var div_icon_603cb15d4c451b68887af4153c990301 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#
#
#                 marker_dfa90f35c1f891c2aaaa04941ed9c929.setIcon(div_icon_603cb15d4c451b68887af4153c990301);
#
#
#             var marker_ba5b61e973f1e562749a8603cdcffdef = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_4d72d1bd288613c95ebb2cbe5dee1fae);
#
#
#             var icon_5bad6626b0079cf667ceab157752d476 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c3d533693ec72d1c98b9ba7815a96f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb1d6d325c74e7bf73509b8921804b5f = $(`&lt;div id=&quot;html_cb1d6d325c74e7bf73509b8921804b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_c3d533693ec72d1c98b9ba7815a96f1b.setContent(html_cb1d6d325c74e7bf73509b8921804b5f);
#
#
#
#         marker_ba5b61e973f1e562749a8603cdcffdef.bindPopup(popup_c3d533693ec72d1c98b9ba7815a96f1b)
#         ;
#
#
#
#
#                 marker_ba5b61e973f1e562749a8603cdcffdef.setIcon(icon_5bad6626b0079cf667ceab157752d476);
#
#
#             var marker_e2f946c82d942093f3e3b5e36cdd8eef = L.marker(
#                 [28.61230197, -80.77735648000001],
#                 {
# }
#             ).addTo(map_4d72d1bd288613c95ebb2cbe5dee1fae);
#
#
#             var icon_5b7fbac6ce4fc12d132580ca896c3c02 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2e18919677a0510

# %% [markdown]
# ## Summary of Launch Site Proximities
#
# Based on our calculations from `coastline_df` and `proximities_df`:
#
# *   **Are launch sites in close proximity to railways?**
#     *   Yes, launch sites are generally in close proximity to railways. The calculated distances to hypothetical railway points ranged from approximately 6.38 km (VAFB SLC-4E) to 15.03 km (CCAFS LC-40, CCAFS SLC-40, KSC LC-39A).
#
# *   **Are launch sites in close proximity to highways?**
#     *   Yes, launch sites are also in close proximity to highways. The distances to hypothetical highway points ranged from approximately 6.78 km (VAFB SLC-4E) to 10.02 km (CCAFS LC-40, CCAFS SLC-40, KSC LC-39A).
#
# *   **Are launch sites in close proximity to coastline?**
#     *   Yes, all launch sites are very close to the coastline, as expected. The distances to our hypothetical coastline points ranged from approximately 1.37 km (VAFB SLC-4E) to 1.47 km (Florida sites).
#
# *   **Do launch sites keep certain distance away from cities?**
#     *   While not extremely far, launch sites do maintain a noticeable distance from major city centers. The distances to hypothetical city points ranged from approximately 12.76 km (VAFB SLC-4E) to 20.31 km (CCAFS LC-40, CCAFS SLC-40, KSC LC-39A). This suggests a preference for locations outside immediate urban areas, likely for safety and operational reasons.
